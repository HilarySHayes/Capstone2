# %%
import os
import gpxpy.gpx
import pandas as pd
import gzip
import seaborn as sns
import matplotlib.pyplot as plt
from fitparse import FitFile

# %% [markdown]
# In command line unzipped the files in the activities folder using:
#
# gzip -d *.gz

# %%
fit_files = [x for x in os.listdir('../data/MB_Strava/activities') if x.endswith(".fit.gz")]
gpx_files = [x for x in os.listdir('../data/MB_Strava/activities') if x.endswith(".gpx")]

# %%
def semicir_to_degs(semicirc):
    return semicirc * (180 / 2**31)

def read_fitfile(filename):
    try:
        fitfile = FitFile(gzip.open(filename))
        df = pd.DataFrame([{d['name']: d['value'] for d in r.as_dict()['fields']} 
                                   for r in fitfile.get_messages('record')])
        df['position_lat'] = df['position_lat'].map(semicir_to_degs)
        df['position_long'] = df['position_long'].map(semicir_to_degs)
        df.set_index("timestamp", inplace=True)
        return df
    except Exception as e:
        print(e)

# %%
onerec_df = read_fitfile('../data/MB_Strava/activities/4469887026.fit.gz')
onerec_df.drop('unknown_88', axis=1)
# Out:
#                      position_lat  position_long  distance  enhanced_speed  \
# timestamp
# 2020-10-10 11:01:27     39.497363    -106.136233      1.18           1.362
# 2020-10-10 11:01:28     39.497366    -106.136222      2.09           1.076
# 2020-10-10 11:01:29     39.497361    -106.136211      2.70           1.116
# 2020-10-10 11:01:30     39.497363    -106.136191      4.41           1.358
# 2020-10-10 11:01:31     39.497365    -106.136169      6.28           1.547
# ...                           ...            ...       ...             ...
# 2020-10-10 12:42:04     39.494008    -106.112020   6778.54           1.295
# 2020-10-10 12:42:05     39.493999    -106.112010   6779.87           1.296
# 2020-10-10 12:42:06     39.493994    -106.112003   6780.65           1.279
# 2020-10-10 12:42:07     39.493993    -106.112001   6780.83           1.242
# 2020-10-10 12:42:08     39.493987    -106.112006   6781.47           0.901
#
#                      speed  heart_rate  cadence
# timestamp
# 2020-10-10 11:01:27  1.362          92       83
# 2020-10-10 11:01:28  1.076          92        0
# 2020-10-10 11:01:29  1.116          92        0
# 2020-10-10 11:01:30  1.358          92        0
# 2020-10-10 11:01:31  1.547          92        0
# ...                    ...         ...      ...
# 2020-10-10 12:42:04  1.295         120       58
# 2020-10-10 12:42:05  1.296         119       56
# 2020-10-10 12:42:06  1.279         116       55
# 2020-10-10 12:42:07  1.242         114       55
# 2020-10-10 12:42:08  0.901         114       55
#
# [5895 rows x 7 columns]

# %%
#     df['timestamp'] = pd.to_datetime(df['timestamp'])
#     df['elapsed_time'] = (df['timestamp'] - df['timestamp'].min()).dt.total_seconds()

# %%
coordinates_df = {}
for i in range(len(fit_files)):
    try:
        coordinates_df[i] = read_fitfile('./MB/activities/' + fit_files[i])[['position_lat', 'position_long']]
    except:
        print(fit_files[i])
# Out:
# 4469887026.fit
# 4852875727.fit
# 3433322362.fit
# 4204903576.fit
# 3833433783.fit
# 4393503376.fit
# 4969693556.fit
# 3833460132.fit
# 4671837571.fit
# 4113720486.fit
# 4751604008.fit
# 3336352485.fit
# 4202524181.fit
# 574938504.fit
# 5008744539.fit
# 3433324262.fit
# 3959288749.fit
# 4102116572.fit
# 4690902412.fit
# 3833459163.fit
# 5230229273.fit
# 3833426789.fit
# 1928103708.fit
# 5052565895.fit
# 4194445417.fit
# 3530827081.fit
# 4946821327.fit
# 3394043677.fit
# 3833449004.fit
# 4672168172.fit
# 3941358668.fit
# 3340168310.fit
# 4738667682.fit
# 575750404.fit
# 3833438830.fit
# 2927279243.fit
# 5295914774.fit
# 3410389604.fit
# 4965168913.fit
# 4210287267.fit
# 4152439370.fit
# 4769320176.fit
# 3833419232.fit
# 3606299049.fit
# 3606311598.fit
# 3507738070.fit
# 4794734190.fit
# 5049408341.fit
# 2927289981.fit
# 4697225542.fit
# 2927273024.fit
# 3294717200.fit
# 4804337711.fit
# 4219549841.fit
# 4370366371.fit
# 5212472624.fit
# 4914529561.fit
# 4118389032.fit
# 2927268363.fit
# 4559468545.fit
# 4559457986.fit
# 4559453262.fit
# 4559470134.fit
# 5094166295.fit
# 2927261769.fit
# 3833431783.fit
# 3326860474.fit
# 3961333668.fit
# 5205914296.fit
# 4136455963.fit
# 3518801371.fit
# 4672367017.fit
# 4134941066.fit
# 4762204983.fit
# 4652688441.fit
# 5125039344.fit
# 4914828829.fit
# 3291659823.fit
# 4590920809.fit
# 3858533367.fit
# 3993999500.fit
# 3018231698.fit
# 3433329970.fit
# 3540425096.fit
# 4232209479.fit
# 3606302294.fit
# 1865981957.fit
# 4734332837.fit
# 4056014603.fit
# 2927284069.fit
# 4234007038.fit
# 4161143830.fit
# 1865983100.fit
# 3941360220.fit
# 4437463368.fit
# 3398977970.fit
# 4690904571.fit
# 4914208237.fit
# 3486235322.fit
# 4913141172.fit
# 4232705399.fit
# 4282730841.fit
# 4436377680.fit
# 4189361092.fit
# 4559461841.fit
# 2927277583.fit
# 4707481540.fit
# 4721070515.fit
# 1928122994.fit
# 4403835249.fit
# 4140524408.fit
# 3175229216.fit
# 3833442722.fit
# 4566336729.fit
# 2927275974.fit
# 1928121906.fit
# 4193787514.fit
# 4591104903.fit
# 4566310049.fit
# 3608966408.fit
# 3941357666.fit
# 4819018227.fit
# 4907182884.fit
# 4192690180.fit
# 1928100458.fit
# 3833427972.fit
# 1928116986.fit
# 5043585474.fit
# 4666689566.fit
# 3833440526.fit
# 5033233074.fit
# 3374649152.fit
# 5065993374.fit
# 4666905421.fit
# 3833451629.fit
# 3853432597.fit
# 4145036383.fit
# 4571129731.fit
# 2927259084.fit
# 3606308910.fit
# 4449638143.fit
# 4469887916.fit
# 4879635080.fit
# 4874492284.fit
# 3868981523.fit
# 5230230418.fit
# 3975952949.fit
# 4993516020.fit
# 4861876113.fit
# 3833437225.fit
# 4783914342.fit
# 3840533776.fit
# 4270596149.fit
# 1928110464.fit
# 3833457089.fit
# 1959884293.fit
# 4861873283.fit
# 5072498538.fit
# 5260373109.fit
# 5089037997.fit
# 1928104606.fit
# 4781597245.fit
# 4700508514.fit
# 4800434461.fit
# 4561405657.fit
# 3486243112.fit
# 4653004190.fit
# 4423637425.fit
# 2927271294.fit
# 1928112648.fit
# 4671839658.fit
# 4340282106.fit
# 4162225434.fit
# 4113560519.fit
# 4623569729.fit
# 3885494384.fit
# 4672339653.fit
# 5271422460.fit
# 5119013600.fit
# 4677985758.fit
# 4279634924.fit
# 3846909489.fit
# 4559464294.fit
# 5186883730.fit
# 1928111426.fit
# 4341127831.fit
# 4711267421.fit
# 4559458800.fit
# 3941356758.fit
# 4993235042.fit
# 3018233787.fit
# 1941984389.fit
# 3489060488.fit
# 3178360972.fit
# 5186884683.fit
# 2936735031.fit
# 5193919073.fit
# 3433328208.fit
# 4924698628.fit
# 4559455079.fit
# 1865980818.fit
# 4618473762.fit
# 4987193210.fit
# 4959301305.fit
# 4454725588.fit
# 3833422593.fit
# 3433326190.fit
# 2927292869.fit
# 4688386335.fit
# 3941361646.fit
# 4469884036.fit
# 4409789128.fit
# 4559474704.fit
# 4862416732.fit
# 3498476603.fit
# 3532069778.fit
# 5096992584.fit
# 4954444749.fit
# 4377352035.fit
# 3897603511.fit
# 3606295755.fit
# 4343108685.fit
# 2927274725.fit
# 4559451368.fit
# 4089326356.fit
# 3606322128.fit
# 1865977049.fit
# 3018232672.fit
# 4701622538.fit
# 3833428081.fit
# 3018235694.fit
# 4229732803.fit
# 4242586685.fit
# 3833446990.fit
# 4559467351.fit
# 4934830329.fit
# 3141436673.fit
# 3537095720.fit
# 4852113918.fit
# 2927264446.fit
# 2944784550.fit
# 3486245812.fit
# 2927269943.fit
# 1928121128.fit
# 3941361093.fit
# 3394041807.fit
# 4225288106.fit
# 3144078040.fit
# 4648629789.fit
# 4992599008.fit
# 4102106296.fit
# 2927287904.fit
# 3606324789.fit
# 5266062065.fit
# 2927303609.fit
# 4762206290.fit
# 3291661872.fit
# 4692432954.fit
# 4725297579.fit
# 3326859466.fit
# 4852115601.fit
# 3486240362.fit
# 3335899593.fit
# 5049648763.fit
# 3833420948.fit
# 1928108786.fit
# 4796376340.fit
# 4861878336.fit
# 4252833142.fit
# 4902252177.fit
# 4189005991.fit
# 4351416498.fit
# 3954449281.fit
# 4419171110.fit
# 2927285123.fit
# 4383618539.fit
# 3833430145.fit
# 3323689155.fit
# 4319587142.fit
# 3833422917.fit
# 2915551275.fit
# 3833444476.fit
# 3833449813.fit
# 3397015976.fit
# 4980915976.fit
# 1928126384.fit
# 4868297931.fit
# 4165780274.fit
# 4862117644.fit
# 3606318362.fit
# 3504115235.fit
# 4626628431.fit
# 3833464412.fit
# 4239292692.fit
# 2944782958.fit
# 3941361343.fit
# 4353972203.fit
# 4304639915.fit
# 5077767912.fit
# 1928119773.fit
# 1928108118.fit
# 3291663741.fit
# 4885212075.fit
# 4861880561.fit
# 4442525289.fit
# 4739860004.fit
# 3606305244.fit
# 4588569187.fit
# 5200011590.fit
# 3358246404.fit
# 3141325181.fit
# 4292363755.fit
# 3447746162.fit
# 4559459756.fit
# 4089331853.fit
# 3018234705.fit
# 1865981391.fit
# 1928106527.fit
# 3950293523.fit
# 3843767461.fit
# 2915551896.fit
# 2927291250.fit
# 4339618862.fit
# 4819019581.fit
# 4182948678.fit
# 576824560.fit
# 4794735308.fit
# 3512240144.fit
# 1928114254.fit
# 5277935702.fit
# 4588573469.fit
# 4456297471.fit
# 4571128253.fit
# 4436380728.fit
# 3833435470.fit
# 5249737121.fit
# 3447743427.fit
# 2927260535.fit
# 4658590755.fit
# 4941233210.fit
# 4762208426.fit
# 3318968967.fit
# 4764830396.fit
# 4270594721.fit
# 2927286264.fit
# 4431581973.fit
# 5186882484.fit
# 3141326329.fit
# 2936733547.fit
# 1865980116.fit
# 1941985026.fit
# 4897408261.fit
# 5110599046.fit
# 4891859107.fit
# 2927263003.fit
# 1959890271.fit
# 3486237994.fit
# 1928123788.fit
# 3833462099.fit
# 4089338904.fit
# 4300260750.fit
# 1928101924.fit
# 3343485243.fit
# 3833424557.fit
# 1865982648.fit
# 4399447370.fit
# 4631761982.fit
# 4573965785.fit

# %% [markdown]
# ### Look into why files above including '4690902412.fit' won't load.

# %%
heatmap_coords_df = pd.concat(coordinates_df, ignore_index = True)
heatmap_coords_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6d06396dea21> in <module>
# ----> 1 heatmap_coords_df = pd.concat(coordinates_df, ignore_index = True)
#       2 heatmap_coords_df
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     293         verify_integrity=verify_integrity,
#     294         copy=copy,
# --> 295         sort=sort,
#     296     )
#     297
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     340
#     341         if len(objs) == 0:
# --> 342             raise ValueError("No objects to concatenate")
#     343
#     344         if keys is None:
#
# ValueError: No objects to concatenate

# %% [markdown]
# # Work on gpx files (only started)

# %%
gpx = gpxpy.parse(open('./KM_Strava/activities/4970268800.gpx'))
track_coords = [[point.latitude, point.longitude, point.elevation] 
                            for track in gpx.tracks 
                                for segment in track.segments 
                                    for point in segment.points]
pd.DataFrame(track_coords, columns=['Latitude', 'Longitude', 'Elevation'])
# Out:
#        Latitude   Longitude  Elevation
# 0     39.567243 -106.085998     2783.8
# 1     39.566986 -106.085617     2784.2
# 2     39.566976 -106.085576     2784.2
# 3     39.566967 -106.085535     2784.2
# 4     39.567041 -106.085516     2784.3
# ...         ...         ...        ...
# 5101  39.569587 -106.097693     2772.6
# 5102  39.569587 -106.097693     2772.6
# 5103  39.569587 -106.097693     2772.6
# 5104  39.569587 -106.097693     2772.6
# 5105  39.569587 -106.097693     2772.6
#
# [5106 rows x 3 columns]

# %%
#track_coords

# %%
# for track in gpx.tracks:
#     for segment in track.segments:
#         for point in segment.points:
#             print(point)

# %%
#gpx.tracks[0].segments[0].points

# %%
#ignore
gpx_track = gpx.tracks[0]
print("Name: " + gpx_track.name)
print("Description: " + str(gpx_track.description))
print("Start: " + str(gpx_track.get_time_bounds().start_time.isoformat()))
print("End: " + str(gpx_track.get_time_bounds().end_time))
 
bounds = gpx_track.get_bounds()
print("Latitude Bounds: (%f, %f)" % (bounds.min_latitude, bounds.max_latitude))
print("Longitude Bounds: (%f, %f)" % (bounds.min_longitude, bounds.max_longitude))
print("Duration: ", gpx_track.get_duration())
# Out:
# Name: Daycare commute
# Description: None
# Start: 2021-03-18T23:01:47+00:00
# End: 2021-03-19 00:26:58+00:00
# Latitude Bounds: (39.564648, 39.577861)
# Longitude Bounds: (-106.098048, -106.051350)
# Duration:  5111.0

# %% [markdown]
# # Investigating activities dataframe

# %% [markdown]
# ### KM Activities = 1566 activities, 15 different types of activities

# %%
df = pd.read_csv('./KM_Strava/activities.csv')
parsed_activities = df.iloc[:,(df.isnull().sum(axis = 0) <= 500).values].set_index('Activity Date')
len(parsed_activities)
# Out:
# 1566

# %%
parsed_activities.tail(2)
# Out:
#                           Activity ID      Activity Name    Activity Type  \
# Activity Date
# Mar 19, 2021, 3:39:43 PM   4974369592  Crystal Exploring  Backcountry Ski
# Mar 23, 2021, 8:22:20 PM   4999211531         🎿 👎 🪂 👍 ⛷   Backcountry Ski
#
#                           Elapsed Time  Distance Commute  \
# Activity Date
# Mar 19, 2021, 3:39:43 PM         12409     10.22   False
# Mar 23, 2021, 8:22:20 PM          8935      8.04   False
#
#                                            Filename  Elapsed Time.1  \
# Activity Date
# Mar 19, 2021, 3:39:43 PM  activities/4974369592.gpx         12409.0
# Mar 23, 2021, 8:22:20 PM  activities/4999211531.gpx          8935.0
#
#                           Moving Time    Distance.1  Max Speed  \
# Activity Date
# Mar 19, 2021, 3:39:43 PM       9266.0  10226.099609        9.3
# Mar 23, 2021, 8:22:20 PM       6127.0   8042.100098        9.1
#
#                           Elevation Gain  Elevation Low  Elevation High  \
# Activity Date
# Mar 19, 2021, 3:39:43 PM      995.585999    3104.000000     3697.800049
# Mar 23, 2021, 8:22:20 PM      803.637390    2772.399902     3559.500000
#
#                           Max Grade  Average Grade  Commute.1
# Activity Date
# Mar 19, 2021, 3:39:43 PM  50.000000       0.048894        0.0
# Mar 23, 2021, 8:22:20 PM  48.599998      -0.036060        0.0

# %%
parsed_activities['Activity Type'].unique()
# Out:
# array(['Ride', 'Run', 'Hike', 'Backcountry Ski', 'Walk', 'Nordic Ski',
#        'Workout', 'Windsurf', 'Surfing', 'Canoe', 'Rock Climb',
#        'Kitesurf', 'Alpine Ski', 'Kayaking', 'Stand Up Paddling'],
#       dtype=object)

# %%
len(parsed_activities['Activity Type'].unique())
# Out:
# 15

# %%
activity_count = parsed_activities['Activity Type'].value_counts()
fig, ax = plt.subplots(figsize=(12, 6))
_ = sns.barplot(y=activity_count.index, x=activity_count.values, ax=ax, color='blue')

# %% [markdown]
# ### BL Activities = 2406 activities, 19 different types of activities

# %%
df = pd.read_csv('./BL_Strava/activities.csv')
parsed_activities = df.iloc[:,(df.isnull().sum(axis = 0) <= 500).values].set_index('Activity Date')
len(parsed_activities)
# Out:
# 2406

# %%
parsed_activities['Activity Type'].unique()
# Out:
# array(['Ride', 'Run', 'Hike', 'Walk', 'Nordic Ski', 'Backcountry Ski',
#        'Crossfit', 'Stand Up Paddling', 'Canoe', 'Kayaking', 'Swim',
#        'Yoga', 'Rock Climb', 'Alpine Ski', 'Snowshoe', 'Workout',
#        'Water Sport', 'Surfing', 'Weight Training'], dtype=object)

# %%
len(parsed_activities['Activity Type'].unique())
# Out:
# 19

# %%
activity_count = parsed_activities['Activity Type'].value_counts()
fig, ax = plt.subplots(figsize=(12, 6))
_ = sns.barplot(y=activity_count.index, x=activity_count.values, ax=ax, color='blue')

# %% [markdown]
# # Example of a driveaway

# %%
plt.rcParams.update({'font.size': 22})

_ = read_fitfile('./MB_Strava/activities/driveaway.fit')[['position_lat', 
                'position_long','distance', 'speed', 'heart_rate', 'cadence']].plot(figsize=(20,20), subplots=True)
